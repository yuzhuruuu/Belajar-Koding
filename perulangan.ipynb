# %%
for i in range(1, 100):
    print(f"perulangan ke-{i}")
# Out:
# perulangan ke-1
# perulangan ke-2
# perulangan ke-3
# perulangan ke-4
# perulangan ke-5
# perulangan ke-6
# perulangan ke-7
# perulangan ke-8
# perulangan ke-9
# perulangan ke-10
# perulangan ke-11
# perulangan ke-12
# perulangan ke-13
# perulangan ke-14
# perulangan ke-15
# perulangan ke-16
# perulangan ke-17
# perulangan ke-18
# perulangan ke-19
# perulangan ke-20
# perulangan ke-21
# perulangan ke-22
# perulangan ke-23
# perulangan ke-24
# perulangan ke-25
# perulangan ke-26
# perulangan ke-27
# perulangan ke-28
# perulangan ke-29
# perulangan ke-30
# perulangan ke-31
# perulangan ke-32
# perulangan ke-33
# perulangan ke-34
# perulangan ke-35
# perulangan ke-36
# perulangan ke-37
# perulangan ke-38
# perulangan ke-39
# perulangan ke-40
# perulangan ke-41
# perulangan ke-42
# perulangan ke-43
# perulangan ke-44
# perulangan ke-45
# perulangan ke-46
# perulangan ke-47
# perulangan ke-48
# perulangan ke-49
# perulangan ke-50
# perulangan ke-51
# perulangan ke-52
# perulangan ke-53
# ...
